# %% [markdown]
# # IPython

# %% [markdown]
# # Debug

# %%
# def func1(a, b):
#     return a / b

# def func2(x):
#     a = x
#     b = x - 1
#     return func1(a, b)

# %%
# func2(1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 func2(1)
#
# Cell In[1], line 7, in func2(x)
#       4 def func2(x):
#       5     a = x
#       6     b = x - 1
# ----> 7     return func1(a, b)
#
# Cell In[1], line 2, in func1(a, b)
#       1 def func1(a, b):
# ----> 2     return a / b
#
# ZeroDivisionError: division by zero

# %%
# %debug
# Out:
# > c:\users\87724\appdata\local\temp\ipykernel_11488\4021589855.py(2)func1()
#
# 1
# 0

# %% [markdown]
# # Cleanup
