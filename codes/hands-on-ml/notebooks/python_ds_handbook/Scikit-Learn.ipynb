# %% [markdown]
# # Scikit-Learn

# %%
import sklearn
sklearn.show_versions()
# Out:
# System:
#     python: 3.12.13 (main, Aug  5 2026, 17:14:30) [MSC v.1944 64 bit (AMD64)]
# executable: d:\workspace\github\hack-ml\codes\hands-on-ml\.venv\Scripts\python.exe
#    machine: Windows-11-10.0.26200-SP0
#
# Python dependencies:
#       sklearn: 1.9.0
#           pip: None
#    setuptools: 84.0.0
#         numpy: 2.5.2
#         scipy: 1.18.1
#        Cython: None
#        pandas: 3.0.5
#    matplotlib: 3.11.1
#        joblib: 1.6.0
# threadpoolctl: 3.6.0
#      narwhals: 2.25.0
#
# Built with OpenMP: True
#
# threadpoolctl info:
#        user_api: openmp
#    internal_api: openmp
#     num_threads: 20
#          prefix: vcomp
#        filepath: D:\workspace\github\hack-ml\codes\hands-on-ml\.venv\Lib\site-packages\sklearn\.libs\vcomp140.dll
#         version: None
#
#        user_api: blas
#    internal_api: openblas
#     num_threads: 20
#          prefix: libscipy_openblas
# ...

# %% [markdown]
# # Cleanup
