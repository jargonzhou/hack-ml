# %% [markdown]
# # Using Graph Algorithms to Enhance Machine Learning

# %% [markdown]
# # Data
#
# * [Citation Network Dataset](https://www.kaggle.com/datasets/mathurinache/citation-network-dataset): V12: 4,894,081 papers and 45,564,149 citation relationships (2020-04-09)
